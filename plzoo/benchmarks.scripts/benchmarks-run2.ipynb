# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from numpy import median
from numpy import average
import pandas as pd
truffle = [5907, 2112, 1326, 1389, 1348, 1249, 1245, 1271, 1230, 1242, 1255, 1266, 1213, 1284, 1217, 1226, 1238, 1208, 1268, 1231, 1242, 1287, 1238, 1230, 1230, 1221, 1209, 1263, 1208, 1214, 1264, 1230, 1226, 1209, 1201, 1216, 1231, 1349, 1218, 1220, 1259, 1214, 1220, 1236, 1234, 1222, 1207, 1253, 1206, 1223, 1233, 1222, 1212, 1208, 1261, 1233, 1215, 1213, 1290, 1211, 1205, 1233, 1209, 1209, 1213, 1253, 1217, 1242, 1212, 1217, 1241, 1248, 1248, 1216, 1218, 1201, 1234, 1201, 1226, 1213, 1258, 1498, 1211, 1264, 1210, 1224, 1229, 1252, 1216, 1223, 1262, 1275, 1219, 1239, 1284, 1218, 1214, 1202, 1267, 1222]
truffle2=[6030, 1876, 1369, 1180, 1181, 1264, 1215, 1446, 1290, 1187, 1573, 1183, 1192, 1237, 1187, 1186, 1213, 1195, 1177, 1182, 1221, 1187, 1171, 1229, 1176, 1148, 1151, 1161, 1161, 1168, 1205, 1204, 1205, 1203, 1192, 1166, 1193, 1160, 1186, 1175, 1186, 1171, 1153, 1209, 1175, 1187, 1159, 1199, 1179, 1177, 1168, 1201, 1194, 1171, 1248, 1193, 1182, 1185, 1217, 1186, 1168, 1156, 1169, 1176, 1176, 1171, 1163, 1191, 1182, 1207, 1156, 1170, 1160, 1183, 1175, 1188, 1153, 1168, 1178, 1257, 1206, 1169, 1176, 1170, 1178, 1179, 1168, 1172, 1170, 1161, 1151, 1194, 1169, 1173, 1180, 1199, 1190, 1170, 1168, 1202]
interpreter = [4425, 1442, 1309, 1288, 1314, 1276, 1308, 1285, 1292, 1292, 1278, 1288, 1284, 1279, 1642, 1324, 1275, 1388, 1336, 1350, 1383, 1272, 1283, 1271, 1282, 1281, 1304, 1281, 1417, 1349, 1282, 1341, 1353, 1270, 1342, 1383, 1282, 1263, 1262, 1347, 1304, 1277, 1259, 1354, 1277, 1268, 1268, 1369, 1263, 1331, 1273, 1594, 1316, 1358, 1285, 1313, 1265, 1383, 1350, 1330, 1287, 1286, 1259, 1271, 1292, 1283, 1258, 1329, 1305, 1280, 1263, 1265, 1271, 1273, 1261, 1272, 1258, 1319, 1295, 1266, 1263, 1262, 1311, 1282, 1276, 1271, 1271, 1283, 1270, 1293, 1263, 1320, 1259, 1269, 1257, 1267, 1314, 1259, 1288, 1276]

# %%
results = {"truffle": truffle, "truffle2": truffle2, "interpreter": interpreter}
medians = {k: median(v) for k, v in results.items()}



medians = {k: median(v) for k, v in results.items()}
sums = {k: sum(v) for k, v in results.items()}
averages = {k: average(v) for k, v in results.items()}

print({k: len(v) for k, v in results.items()})
print('medians')
for x in sorted(medians.items(), key=lambda x: x[1]):
    print(x)
print('sums')
for x in sorted(sums.items(), key=lambda x: x[1]):
    print(x)
print('avgs')
for x in sorted(averages.items(), key=lambda x: x[1]):
    print(x)


fig, ax = plt.subplots()
plt.xticks(rotation=90)
plt.bar([0,1,2], (medians['truffle'], medians['truffle2'], medians['interpreter']))
ax.set_xticks([0,1,2])
ax.set_xticklabels(['truffle', 'truffle2', 'interpreter'])
plt.show()

plt.figure(figsize=(10,10))
handles=[]
for k, v in results.items():
    # plt.axhline(y=median(v))
    h, = plt.plot(v, label=k)
    handles.append(h)
plt.legend(handles=handles)
plt.show()
# Out:
# {'truffle': 100, 'truffle2': 100, 'interpreter': 100}
# medians
# ('truffle2', 1181.5)
# ('truffle', 1229.5)
# ('interpreter', 1283.0)
# sums
# ('truffle2', 124857)
# ('truffle', 129446)
# ('interpreter', 133507)
# avgs
# ('truffle2', 1248.57)
# ('truffle', 1294.46)
# ('interpreter', 1335.07)

# %%
truffle = [10558, 6246, 6233, 6336, 6387, 5534, 6574, 5388, 5263, 5589, 5395, 5155, 5350, 5202, 5212, 5403, 5323, 5320, 5380, 5235, 5213, 5428, 5285, 5323, 5408, 5331, 5344, 5425, 5291, 5284, 5429, 5280, 5269, 5317, 5259, 5299, 5344, 5306, 5329, 5313, 5385, 5286, 5451, 5351, 5302, 5397, 5287, 5293, 5454, 5292, 5282, 5615, 5330, 5306, 5533, 5261, 5315, 5371, 5341, 5301, 5471, 5319, 5253, 5357, 5406, 5329, 5425, 5328, 5255, 5522, 5385, 5261, 5358, 5312, 5491, 5460, 5271, 5291, 5346, 5278, 5287, 5351, 5302, 5701, 5414, 5286, 5350, 5442, 5273, 5296, 5375, 5271, 5350, 5457, 5422, 5333, 5340, 5309, 5318, 5306]

interpreter = [9212, 6454, 5984, 6591, 5877, 6341, 6151, 5806, 5999, 6094, 5973, 6707, 5659, 6142, 5693, 6090, 5638, 5718, 5783, 5654, 5741, 5742, 5741, 5622, 5694, 5609, 5683, 5709, 5691, 5648, 5652, 5766, 5843, 5571, 5593, 5821, 5579, 5611, 5962, 5656, 5575, 5882, 5604, 5578, 5639, 5609, 5683, 5657, 5540, 5802, 5616, 5554, 5560, 5562, 5703, 5764, 5556, 5608, 5736, 5582, 5566, 5744, 5712, 5757, 5599, 5644, 5881, 5617, 5599, 5709, 5576, 5552, 5578, 5692, 5647, 5711, 5542, 5626, 5696, 5539, 5689, 5602, 5660, 5725, 5546, 5645, 5713, 5628, 5513, 5710, 5743, 5581, 5650, 5614, 5623, 5648, 5562, 5682, 5761, 5582]


results = {"truffle": truffle, "interpreter": interpreter}
medians = {k: median(v) for k, v in results.items()}



medians = {k: median(v) for k, v in results.items()}
sums = {k: sum(v) for k, v in results.items()}
averages = {k: average(v) for k, v in results.items()}

print({k: len(v) for k, v in results.items()})
print('medians')
for x in sorted(medians.items(), key=lambda x: x[1]):
    print(x)
print('sums')
for x in sorted(sums.items(), key=lambda x: x[1]):
    print(x)
print('avgs')
for x in sorted(averages.items(), key=lambda x: x[1]):
    print(x)


fig, ax = plt.subplots()
plt.xticks(rotation=90)
plt.bar([0,1], (medians['truffle'], medians['interpreter']))
ax.set_xticks([0,1])
ax.set_xticklabels(['truffle','interpreter'])
plt.show()

plt.figure(figsize=(10,10))
handles=[]
for k, v in results.items():
    # plt.axhline(y=median(v))
    h, = plt.plot(v, label=k)
    handles.append(h)
plt.legend(handles=handles)
plt.show()
# Out:
# {'truffle': 100, 'interpreter': 100}
# medians
# ('truffle', 5330.5)
# ('interpreter', 5659.5)
# sums
# ('truffle', 545014)
# ('interpreter', 576174)
# avgs
# ('truffle', 5450.14)
# ('interpreter', 5761.74)
