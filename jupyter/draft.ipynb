# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # TODO
#
# Refaire les xp ci-dessous directement sur le serveur, beaucoup trop de variance avec les activités du système sur la machine!

# %%
dispatch_on_eval=[0 for _ in range(0,50)]
# actually dispatch on nextLine but no trace of compilation in the idealgraph
no_dispatch=[0 for _ in range(0,50)]
dispatch_on_callfunc=[0 for _ in range(0,50)]


#print(sum(dispatch_on_eval))
#print(sum(no_dispatch))
#print(sum(dispatch_on_callfunc))

plt.title('BOA: fibonacci')
plt.plot(dispatch_on_eval, label='dispatch on eval')
plt.plot(no_dispatch, label='no dispatch')
plt.plot(dispatch_on_callfunc, label='dispatch on callFunc')
plt.legend()
plt.show()

plt.title('BOA: fibonacci')
plt.hist(dispatch_on_eval, label='dispatch on eval')
plt.hist(no_dispatch, label='no dispatch')
plt.hist(dispatch_on_callfunc, label='dispatch on callFunc')
plt.legend()
plt.show()

# %%
no_dispatch=[8793, 7124, 6967, 6866, 6895, 6909, 6949, 6958, 6958, 6947, 6973, 7057, 6964, 7011, 7015, 7070, 7029, 7033, 6985, 7045, 7035, 6982, 7011, 6973, 7030, 7047, 7035, 7051, 7063, 7120, 7018, 7071, 7063, 7062, 7068, 7075, 7096, 7086, 7061, 7080, 7044, 7089, 7053, 7070, 7104, 7066, 7105, 7077, 7078, 7070]
dispatch_on_method_call=[8331, 7875, 7809, 7714, 7882, 7776, 7804, 7872, 7775, 7912, 7866, 7843, 7893, 7916, 7855, 7887, 7860, 8012, 8031, 7949, 7944, 7917, 7936, 7965, 7803, 7858, 7940, 7877, 7827, 7955, 7914, 7900, 7893, 7905, 7887, 7999, 7987, 7920, 7813, 7895, 7921, 8030, 7908, 8024, 7961, 7942, 8052, 8012, 8060, 8036]
dispatch_on_methodcall_call=[9130, 8825, 8349, 8223, 8280, 8563, 8477, 8150, 8272, 8083, 8417, 8330, 8162, 8471, 8337, 8117, 8362, 8378, 8168, 8394, 8323, 8226, 8371, 8471, 8288, 8332, 8263, 8375, 8482, 8577, 8400, 8532, 8395, 8310, 8314, 8298, 8214, 8426, 8519, 8284, 8352, 8514, 8231, 8612, 8306, 8326, 8332, 8375, 8253, 8285]
dispatch_on_block_evaluatestatement=[8485, 8434, 8077, 8416, 7993, 8294, 8140, 7936, 8151, 8097, 8295, 8330, 8306, 8372, 8203, 8307, 8278, 8344, 8147, 8238, 8252, 8120, 8340, 8419, 8440, 8174, 8237, 8333, 8413, 8315, 8443, 8397, 8237, 8190, 8168, 8374, 8097, 8406, 8103, 8374, 8243, 8338, 8424, 8182, 8302, 8298, 8691, 8347, 8281, 8104]
dispatch_on_expression_evaluateexpression=[14069, 11682, 11158, 11665, 10255, 10596, 10307, 10611, 10397, 10451, 10295, 9638, 10402, 11058, 11433, 10556, 10376, 10399, 9973, 10473, 10725, 10328, 11234, 10703, 10301, 10102, 10495, 10556, 9803, 10480, 10351, 10537, 9865, 10387, 10318, 9902, 10555, 12631, 11783, 10858, 10016, 10530, 10339, 10509, 10063, 9882, 10228, 10546, 10419, 10329]


plt.title('MiniJava: fibonacci')
plt.plot(no_dispatch, label='no dispatch')
plt.plot(dispatch_on_method_call, label='dispatch on Method.call')
plt.plot(dispatch_on_methodcall_call, label='dispatch on MethodCall.call')
plt.plot(dispatch_on_block_evaluatestatement, label='dispatch on Block.evaluateStatement')
plt.plot(dispatch_on_expression_evaluateexpression, label='dispatch_on_expression_evaluateexpression')
plt.legend()
plt.show()

plt.title('MiniJava: fibonacci')
plt.hist(no_dispatch, label='no dispatch')
plt.hist(dispatch_on_method_call, label='dispatch on Method.call')
plt.hist(dispatch_on_methodcall_call, label='dispatch on MethodCall.call')
plt.hist(dispatch_on_block_evaluatestatement, label='dispatch on Block.evaluateStatement')
plt.hist(dispatch_on_expression_evaluateexpression, label='dispatch_on_expression_evaluateexpression')
plt.legend()
plt.show()

# %%
no_dispatch=[0 for _ in range(0,50)]
dispatch_on_call=[0 for _ in range(0,50)]

plt.title('MiniJava: fannkuchredux')
plt.plot(no_dispatch, label='no dispatch')
plt.plot(dispatch_on_call, label='dispatch on call')
plt.legend()
plt.show()

plt.title('MiniJava: fannkuchredux')
plt.hist(no_dispatch, label='no dispatch')
plt.hist(dispatch_on_call, label='dispatch on call')
plt.legend()
plt.show()
