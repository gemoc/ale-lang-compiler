# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
dispatch_on_eval=[9878, 7935, 6864, 14417, 9205, 9543, 5967, 7057, 6433, 7981, 6085, 5299, 7540, 5684, 7985, 7857, 6715, 12187, 9643, 5959, 4419, 4988, 5119, 5202, 5516, 5074, 6321, 4917, 6048, 7576, 6979, 5645, 6118, 5952, 7320, 5601, 5062, 5881, 7882, 5543, 4975, 4945, 4324, 5955, 5211, 4794, 5299, 5455, 4088, 4474]
# actually dispatch on nextLine but no trace of compilation in the idealgraph
no_dispatch=[5097, 2588, 2118, 1167, 1068, 1144, 1175, 1432, 1444, 1221, 1072, 1178, 1149, 1557, 2780, 2867, 2454, 2383, 1956, 1977, 1739, 1961, 1482, 1547, 1438, 1386, 1551, 1824, 1304, 1555, 1483, 1821, 1515, 1374, 1426, 1680, 1808, 1490, 1380, 1499, 1302, 1510, 1546, 1461, 1441, 1614, 1592, 1231, 1327, 1706]
dispatch_on_callfunc=[4240, 2255, 1423, 1151, 1121, 1355, 1512, 1151, 1118, 1095, 1125, 1159, 1134, 1102, 1078, 1099, 1107, 1229, 1093, 1087, 1147, 1074, 1094, 1093, 1092, 1081, 1105, 1248, 1093, 1078, 1131, 1094, 1096, 1125, 1107, 1171, 1080, 1079, 1092, 1115, 1082, 1085, 1094, 1078, 1094, 1076, 1067, 1126, 1084, 1183]


#print(sum(dispatch_on_eval))
#print(sum(no_dispatch))
#print(sum(dispatch_on_callfunc))

plt.title('BOA: fibonacci')
plt.plot(dispatch_on_eval, label='dispatch on eval')
plt.plot(no_dispatch, label='no dispatch')
plt.plot(dispatch_on_callfunc, label='dispatch on callFunc')
plt.legend()
plt.show()

plt.title('BOA: fibonacci')
plt.hist(dispatch_on_eval, label='dispatch on eval')
plt.hist(no_dispatch, label='no dispatch')
plt.hist(dispatch_on_callfunc, label='dispatch on callFunc')
plt.legend()
plt.show()

# %%
no_dispatch=[10617, 9268, 8730, 8726, 8770, 8782, 8824, 8728, 8886, 8670, 8695, 8848, 8682, 8750, 8805, 8813, 8846, 8891, 8875, 8757, 9003, 8840, 8795, 8753, 8750, 9038, 9126, 9017, 8976, 8896, 8921, 9000, 9001, 8815, 8960, 9128, 8859, 8862, 8949, 9005, 8839, 8914, 9137, 9185, 8734, 8823, 9042, 8842, 8847, 9190]
dispatch_on_call=[13186, 12889, 8453, 8519, 8512, 8852, 8432, 8505, 8633, 8588, 8717, 8542, 8838, 8490, 8507, 8447, 8540, 8521, 8597, 8634, 8729, 8457, 8489, 9024, 8633, 8699, 8798, 8813, 8632, 8603, 8672, 8623, 8725, 9065, 8979, 8925, 8768, 9087, 9129, 9007, 8737, 8497, 8959, 8558, 8613, 8972, 8621, 9093, 9021, 9393]

plt.title('MiniJava: fibonacci')
plt.plot(no_dispatch, label='no dispatch')
plt.plot(dispatch_on_call, label='dispatch on call')
plt.legend()
plt.show()

plt.title('MiniJava: fibonacci')
plt.hist(no_dispatch, label='no dispatch')
plt.hist(dispatch_on_call, label='dispatch on call')
plt.legend()
plt.show()
