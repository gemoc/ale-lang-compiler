True, 'boa.ArithOpDivide.eval': True, 'boa.ArithOpMinus.eval': True, 'boa.ArithOpRemainder.eval': True, 'boa.Bool.eval': True, 'boa.BoolOpAnd.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.Fun.eval': True, 'boa.If.eval': True, 'boa.Int.eval': True, 'boa.This.eval': True, 'times': [3730, 1173, 894, 884, 875, 861, 883, 863, 862, 857, 954, 855, 857, 851, 853, 853, 871, 851, 852, 850, 855, 852, 851, 853, 852, 868, 850, 856, 854, 849, 848, 859, 851, 853, 850, 851, 850, 849, 849, 850, 852, 851, 850, 856, 851, 851, 854, 853, 850, 853]}, {'boa.TopLevelCmd.nextLine': True, 'boa.Expr.eval': True, 'boa.Var.eval': True, 'boa.App.callFunc': True, 'boa.ArithOpPlus.eval': True, 'boa.ArithOpRemainder.eval': True, 'boa.Assign.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.Project.eval': True, 'boa.This.eval': True, 'times': []}, {'boa.TopLevelCmd.nextLine': True, 'boa.Expr.eval': True, 'boa.Expr.nextLine': True, 'boa.Var.eval': True, 'boa.App.callFunc': True, 'boa.ArithOpDivide.eval': True, 'boa.ArithOpTimes.eval': True, 'boa.Assign.eval': True, 'boa.BoolOpAnd.eval': True, 'boa.CmpOpEqual.eval': True, 'boa.CmpOpUnequal.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.If.eval': True, 'boa.Project.project': True, 'boa.Skip.eval': True, 'times': []}, {'boa.TopLevelCmd.nextLine': True, 'boa.Expr.eval': True, 'boa.Var.eval': True, 'boa.BObject.eval': True, 'boa.App.callFunc': True, 'boa.ArithOpPlus.eval': True, 'boa.ArithOpRemainder.eval': True, 'boa.Assign.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.Project.eval': True, 'boa.This.eval': True, 'times': []}, {'boa.TopLevelCmd.nextLine': True, 'boa.Expr.eval': True, 'boa.Var.eval': True, 'boa.App.callFunc': True, 'boa.ArithOpPlus.eval': True, 'boa.ArithOpRemainder.eval': True, 'boa.Assign.eval': True, 'boa.BoolOpAnd.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpEqual.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Fun.eval': True, 'boa.If.eval': True, 'boa.Let.eval': True, 'boa.Not.eval': True, 'boa.Project.eval': True, 'boa.Project.project': True, 'boa.Skip.eval': True, 'boa.This.eval': True, 'boa.With.eval': True, 'times': []}, {'boa.Def.nextLine': True, 'boa.Expr.eval': True, 'boa.App.eval': True, 'boa.ArithOpPlus.eval': True, 'boa.Assign.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpEqual.eval': True, 'boa.CmpOpUnequal.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.If.eval': True, 'boa.Int.eval': True, 'boa.Project.project': True, 'boa.With.eval': True, 'times': []}, {'boa.Def.nextLine': True, 'boa.Expr.eval': True, 'boa.App.eval': True, 'boa.ArithOpPlus.eval': True, 'boa.Assign.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpUnequal.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.Fun.eval': True, 'boa.Int.eval': True, 'boa.Not.eval': True, 'boa.Project.eval': True, 'boa.Project.project': True, 'boa.Skip.eval': True, 'boa.With.eval': True, 'times': []}, {'boa.TopLevelCmd.nextLine': True, 'boa.Expr.eval': True, 'boa.Var.eval': True, 'boa.BObject.eval': True, 'boa.App.callFunc': True, 'boa.ArithOpPlus.eval': True, 'boa.Assign.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpEqual.eval': True, 'boa.CmpOpUnequal.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.If.eval': True, 'boa.Int.eval': True, 'boa.Not.eval': True, 'boa.Project.eval': True, 'boa.Project.project': True, 'boa.Skip.eval': True, 'boa.This.eval': True, 'boa.With.eval': True, 'times': []}, {'boa.TopLevelCmd.nextLine': True, 'boa.Expr.eval': True, 'boa.Expr.nextLine': True, 'boa.Var.eval': True, 'boa.BObject.eval': True, 'boa.ArithOpPlus.eval': True, 'boa.Assign.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpEqual.eval': True, 'boa.CmpOpUnequal.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.If.eval': True, 'boa.Int.eval': True, 'boa.Not.eval': True, 'boa.Seq.eval': True, 'boa.With.eval': True, 'times': []}, {'boa.Def.nextLine': True, 'boa.Expr.eval': True, 'boa.App.eval': True, 'boa.ArithOpMinus.eval': True, 'boa.ArithOpPlus.eval': True, 'boa.ArithOpTimes.eval': True, 'boa.Assign.eval': True, 'boa.BoolOpAnd.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpEqual.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.Fun.eval': True, 'boa.Let.eval': True, 'boa.Not.eval': True, 'boa.Project.eval': True, 'boa.Project.project': True, 'boa.Skip.eval': True, 'boa.This.eval': True, 'boa.With.eval': True, 'times': []}, {'boa.TopLevelCmd.nextLine': True, 'boa.Expr.eval': True, 'boa.Var.eval': True, 'boa.ArithOpMinus.eval': True, 'boa.ArithOpPlus.eval': True, 'boa.ArithOpRemainder.eval': True, 'boa.ArithOpTimes.eval': True, 'boa.Assign.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpLess.eval': True, 'boa.If.eval': True, 'boa.Project.eval': True, 'boa.Project.project': True, 'boa.This.eval': True, 'times': []}, {'boa.TopLevelCmd.nextLine': True, 'boa.Expr.eval': True, 'boa.Var.eval': True, 'boa.BObject.eval': True, 'boa.App.callFunc': True, 'boa.ArithOpPlus.eval': True, 'boa.ArithOpRemainder.eval': True, 'boa.Assign.eval': True, 'boa.BoolOpAnd.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpEqual.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Fun.eval': True, 'boa.If.eval': True, 'boa.Let.eval': True, 'boa.Not.eval': True, 'boa.Project.eval': True, 'boa.Project.project': True, 'boa.Skip.eval': True, 'boa.This.eval': True, 'boa.With.eval': True, 'times': []}, {'boa.TopLevelCmd.nextLine': True, 'boa.Expr.eval': True, 'boa.Var.eval': True, 'boa.App.callFunc': True, 'boa.ArithOpPlus.eval': True, 'boa.ArithOpRemainder.eval': True, 'boa.Assign.eval': True, 'boa.CmpOpEqual.eval': True, 'boa.CmpOpUnequal.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Fun.eval': True, 'boa.If.eval': True, 'boa.Let.eval': True, 'boa.Project.project': True, 'boa.Skip.eval': True, 'boa.This.eval': True, 'boa.With.eval': True, 'times': []}, {'boa.TopLevelCmd.nextLine': True, 'boa.Def.nextLine': True, 'boa.Expr.eval': True, 'boa.Var.eval': True, 'boa.ArithOpMinus.eval': True, 'boa.ArithOpPlus.eval': True, 'boa.ArithOpRemainder.eval': True, 'boa.Bool.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.Project.eval': True, 'boa.This.eval': True, 'times': []}]
results_clean=[x for x in results if len(x['times'])>0]
df_results=pd.DataFrame.from_dict(results).fillna(False)
df_results_clean=df_results[df_results['times'].apply(lambda x: len(x) > 0)]
df_results_clean['avg']=df_results_clean['times'].apply(lambda x: average(x[10:]))
md=df_results_clean.sort_values(by=['avg'])
md = md.drop('times', axis=1)
print(md.describe(include='all'))
print(tabulate(md, tablefmt="pipe", headers="keys"))
# Out:
#        boa.App.callFunc boa.App.eval boa.ArithOpDivide.eval  \
# count                 7            7                      7
# unique                2            2                      2
# top                True         True                   True
# freq                  4            4                      4
# mean                NaN          NaN                    NaN
# std                 NaN          NaN                    NaN
# min                 NaN          NaN                    NaN
# 25%                 NaN          NaN                    NaN
# 50%                 NaN          NaN                    NaN
# 75%                 NaN          NaN                    NaN
# max                 NaN          NaN                    NaN
#
#        boa.ArithOpMinus.eval boa.ArithOpPlus.eval boa.ArithOpRemainder.eval  \
# count                      7                    7                         7
# unique                     2                    2                         2
# ...

# %%
nums = list(range(0, len(results_clean)))

avgs=[average(x['times'][10:]) for x in results_clean]

fig, ax = plt.subplots()
plt.xticks(rotation=90)
plt.bar(nums, tuple(avgs))

plt.figure(figsize=(10,10))
handles=[]
i=0
for x in results_clean:
    # plt.axhline(y=median(v))
    h, = plt.plot(x['times'], label=i)
    handles.append(h)
    i = i + 1
plt.legend(handles=handles)
plt.show()
