# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from numpy import median
from numpy import average
import pandas as pd

time0=[]
time1=[]
time2=[4034, 1778, 1672, 1502, 1489, 1499, 1478, 1481, 1483, 1470, 1491, 1482, 1482, 1495, 1485, 1477, 1493, 1480, 1484, 1471, 1474, 1474, 1492, 1476, 1481, 1480, 1481, 1488, 1491, 1480, 1475, 1470, 1482, 1492, 1484, 1494, 1492, 1489, 1485, 1487, 1489, 1493, 1489, 1489, 1488, 1503, 1489, 1494, 1498, 1484]
time3=[3133, 1279, 1088, 1053, 1034, 1016, 1046, 1017, 1045, 1011, 1007, 1018, 1007, 1005, 1005, 1014, 1008, 1007, 1008, 1005, 1006, 1009, 1009, 1003, 1003, 1005, 1009, 1002, 1006, 995, 1007, 1005, 1001, 1000, 1003, 1004, 994, 993, 1005, 1003, 996, 998, 1001, 997, 999, 1002, 1012, 1004, 999, 1002]
time4=[]
time5=[]
time6=[4080, 1714, 1547, 1512, 1521, 1494, 1505, 1482, 1502, 1492, 1503, 1497, 1498, 1502, 1492, 1488, 1499, 1493, 1484, 1501, 1490, 1500, 1488, 1511, 1485, 1496, 1487, 1487, 1494, 1500, 1492, 1497, 1493, 1497, 1487, 1481, 1494, 1490, 1490, 1493, 1494, 1496, 1506, 1496, 1506, 1499, 1498, 1510, 1503, 1502]
time7=[3249, 1281, 1109, 1068, 1052, 1031, 1043, 1028, 1027, 1021, 1023, 1030, 1018, 1019, 1019, 1018, 1018, 1024, 1021, 1020, 1023, 1027, 1014, 1011, 1019, 1016, 1017, 1019, 1017, 1021, 1022, 1013, 1018, 1018, 1023, 1018, 1021, 1015, 1010, 1012, 1010, 1020, 1017, 1014, 1021, 1019, 1014, 1025, 1022, 1018]
results={
    "time1": time1,
    "time2": time2,
    "time3": time3,
    "time4": time4,
    "time5": time5,
    "time6": time6,
    "time7": time7
}

results_nowarmup={k: v[10:] for (k,v) in results.items()}

nums = list(range(0, len(medians.keys())))

medians={k: median(v) if len(v) > 0 else 0 for (k,v) in results.items()}
medians_nowarmup={k: median(v) if len(v) > 0 else 0 for (k,v) in results_nowarmup.items()}
print(medians)
print(medians_nowarmup)

fig, ax = plt.subplots()
plt.xticks(rotation=90)
plt.bar(nums, tuple(medians.values()))

plt.figure(figsize=(10,10))
handles=[]
for k, v in results.items():
    # plt.axhline(y=median(v))
    h, = plt.plot(v, label=k)
    handles.append(h)
plt.legend(handles=handles)
plt.show()
# Out:
# {'time1': 0, 'time2': 1487.5, 'time3': 1005.0, 'time4': 0, 'time5': 0, 'time6': 1496.5, 'time7': 1019.5}
# {'time1': 0, 'time2': 1486.0, 'time3': 1004.5, 'time4': 0, 'time5': 0, 'time6': 1496.0, 'time7': 1018.5}
