# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from numpy import median
from numpy import average
import pandas as pd
truffle = [5907, 2112, 1326, 1389, 1348, 1249, 1245, 1271, 1230, 1242, 1255, 1266, 1213, 1284, 1217, 1226, 1238, 1208, 1268, 1231, 1242, 1287, 1238, 1230, 1230, 1221, 1209, 1263, 1208, 1214, 1264, 1230, 1226, 1209, 1201, 1216, 1231, 1349, 1218, 1220, 1259, 1214, 1220, 1236, 1234, 1222, 1207, 1253, 1206, 1223, 1233, 1222, 1212, 1208, 1261, 1233, 1215, 1213, 1290, 1211, 1205, 1233, 1209, 1209, 1213, 1253, 1217, 1242, 1212, 1217, 1241, 1248, 1248, 1216, 1218, 1201, 1234, 1201, 1226, 1213, 1258, 1498, 1211, 1264, 1210, 1224, 1229, 1252, 1216, 1223, 1262, 1275, 1219, 1239, 1284, 1218, 1214, 1202, 1267, 1222]
interpreter = [4425, 1442, 1309, 1288, 1314, 1276, 1308, 1285, 1292, 1292, 1278, 1288, 1284, 1279, 1642, 1324, 1275, 1388, 1336, 1350, 1383, 1272, 1283, 1271, 1282, 1281, 1304, 1281, 1417, 1349, 1282, 1341, 1353, 1270, 1342, 1383, 1282, 1263, 1262, 1347, 1304, 1277, 1259, 1354, 1277, 1268, 1268, 1369, 1263, 1331, 1273, 1594, 1316, 1358, 1285, 1313, 1265, 1383, 1350, 1330, 1287, 1286, 1259, 1271, 1292, 1283, 1258, 1329, 1305, 1280, 1263, 1265, 1271, 1273, 1261, 1272, 1258, 1319, 1295, 1266, 1263, 1262, 1311, 1282, 1276, 1271, 1271, 1283, 1270, 1293, 1263, 1320, 1259, 1269, 1257, 1267, 1314, 1259, 1288, 1276]

# %%
results = {"truffle": truffle, "interpreter": interpreter}
medians = {k: median(v) for k, v in results.items()}



medians = {k: median(v) for k, v in results.items()}
sums = {k: sum(v) for k, v in results.items()}
averages = {k: average(v) for k, v in results.items()}

print({k: len(v) for k, v in results.items()})
print('medians')
for x in sorted(medians.items(), key=lambda x: x[1]):
    print(x)
print('sums')
for x in sorted(sums.items(), key=lambda x: x[1]):
    print(x)
print('avgs')
for x in sorted(averages.items(), key=lambda x: x[1]):
    print(x)


fig, ax = plt.subplots()
plt.xticks(rotation=90)
plt.bar([0,1], (medians['truffle'], medians['interpreter']))
ax.set_xticks([0,1])
ax.set_xticklabels(['truffle','interpreter'])
plt.show()

plt.figure(figsize=(10,10))
handles=[]
for k, v in results.items():
    # plt.axhline(y=median(v))
    h, = plt.plot(v, label=k)
    handles.append(h)
plt.legend(handles=handles)
plt.show()
# Out:
# {'interpreter_java8_logo_fractal': 500, 'visitor_java8_logo_fractal': 500, 'revisitor_java8_logo_fractal': 500, 'interpreter_graalvm_logo_fractal': 500, 'visitor_graalvm_logo_fractal': 500, 'revisitor_graalvm_logo_fractal': 500, 'truffle_graalvmtruffle_logo_fractal': 500}
# medians
# ('truffle_graalvmtruffle_logo_fractal', 88.0)
# ('interpreter_graalvm_logo_fractal', 92.0)
# ('revisitor_graalvm_logo_fractal', 94.0)
# ('visitor_graalvm_logo_fractal', 96.0)
# ('interpreter_java8_logo_fractal', 125.0)
# ('revisitor_java8_logo_fractal', 134.0)
# ('visitor_java8_logo_fractal', 146.0)
# sums
# ('truffle_graalvmtruffle_logo_fractal', 47868)
# ('interpreter_graalvm_logo_fractal', 50142)
# ('revisitor_graalvm_logo_fractal', 51619)
# ('visitor_graalvm_logo_fractal', 52045)
# ('interpreter_java8_logo_fractal', 63214)
# ('revisitor_java8_logo_fractal', 67917)
# ('visitor_java8_logo_fractal', 75931)
# avgs
# ('truffle_graalvmtruffle_logo_fractal', 95.736)
# ('interpreter_graalvm_logo_fractal', 100.284)
# ('revisitor_graalvm_logo_fractal', 103.238)
# ('visitor_graalvm_logo_fractal', 104.09)
# ('interpreter_java8_logo_fractal', 126.428)
# ('revisitor_java8_logo_fractal', 135.834)
# ('visitor_java8_logo_fractal', 151.862)

# %%
results = {
  "interpreter_graalvm_boa_fib10": interpreter_graalvm_boa_fib10,
  "interpreter_graalvm_boa_fib15": interpreter_graalvm_boa_fib15,
  "revisitor_graalvm_boa_fib10": revisitor_graalvm_boa_fib10,
  "revisitor_graalvm_boa_fib15": revisitor_graalvm_boa_fib15,
  "visitor_graalvm_boa_fib10": visitor_graalvm_boa_fib10,
  "visitor_graalvm_boa_fib15": visitor_graalvm_boa_fib15
}

medians = {k: median(v) for k, v in results.items()}
sums = {k: sum(v) for k, v in results.items()}
averages = {k: average(v) for k, v in results.items()}
print({k: len(v) for k, v in results.items()})
print(medians)
print(sums)
print(averages)

plt.figure(figsize=(10,10))
handles=[]
for k, v in results.items():
    # plt.axhline(y=median(v))
    h, = plt.plot(v, label=k)
    handles.append(h)
plt.legend(handles=handles)
plt.show()

# %%
results = {
  "interpreter_graalvm_boa_fib15": interpreter_graalvm_boa_fib15,
  "interpreter_java8_boa_fib15": interpreter_java8_boa_fib15,
  "revisitor_graalvm_boa_fib15": revisitor_graalvm_boa_fib15,
  "revisitor_java8_boa_fib15": revisitor_java8_boa_fib15,
  "visitor_graalvm_boa_fib15": visitor_graalvm_boa_fib15,
  "visitor_java8_boa_fib15": visitor_java8_boa_fib15
}

medians = {k: median(v) for k, v in results.items()}
sums = {k: sum(v) for k, v in results.items()}
averages = {k: average(v) for k, v in results.items()}
print({k: len(v) for k, v in results.items()})
print(medians)
print(sums)
print(averages)

print("Medians")
for k, v in medians.items(): print(k, v)
print("Sums")
for k, v in sums.items(): print(k, v)
print("Average")
for k, v in averages.items(): print(k, v)
    
plt.plot([v for k,v in medians.items()])
plt.show()

plt.figure(figsize=(10,10))
handles=[]
for k, v in results.items():
    # plt.axhline(y=median(v))
    h, = plt.plot(v, label=k)
    handles.append(h)
plt.legend(handles=handles)
plt.show()

# %%
results = {
  "interpreter_java8_boa_fib10": interpreter_java8_boa_fib10,
  "interpreter_java8_boa_fib15": interpreter_java8_boa_fib15,
  "revisitor_java8_boa_fib10": revisitor_java8_boa_fib10,
  "revisitor_java8_boa_fib15": revisitor_java8_boa_fib15,
  "visitor_java8_boa_fib10": visitor_java8_boa_fib10,
  "visitor_java8_boa_fib15": visitor_java8_boa_fib15
}

medians = {k: median(v) for k, v in results.items()}
sums = {k: sum(v) for k, v in results.items()}
averages = {k: average(v) for k, v in results.items()}
print({k: len(v) for k, v in results.items()})
print(medians)
print(sums)
print(averages)

print("Medians")
for k, v in medians.items(): print(k, v)
print("Sums")
for k, v in sums.items(): print(k, v)
print("Average")
for k, v in averages.items(): print(k, v)

plt.figure(figsize=(10,10))
handles=[]
for k, v in results.items():
    # plt.axhline(y=median(v))
    h, = plt.plot(v, label=k)
    handles.append(h)
plt.legend(handles=handles)
plt.show()
