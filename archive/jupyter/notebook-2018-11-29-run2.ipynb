boa.Expr.eval': True, 'boa.Var.eval': True, 'boa.ArithOpMinus.eval': True, 'boa.ArithOpPlus.eval': True, 'boa.Assign.eval': True, 'boa.Bool.eval': True, 'boa.BoolOpAnd.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpUnequal.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.If.eval': True, 'boa.Int.eval': True, 'boa.Let.eval': True, 'boa.Seq.eval': True, 'boa.This.eval': True, 'times': []}, {'boa.Expr.nextLine': True, 'boa.Var.eval': True, 'boa.ArithOpDivide.eval': True, 'boa.ArithOpPlus.eval': True, 'boa.Bool.eval': True, 'boa.CmpOpUnequal.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.Fun.eval': True, 'boa.Int.eval': True, 'boa.Let.eval': True, 'boa.Seq.eval': True, 'boa.Skip.eval': True, 'boa.This.eval': True, 'boa.With.eval': True, 'times': [3364, 1437, 1252, 1213, 1184, 1230, 1189, 1211, 1170, 1168, 1164, 1172, 1158, 1162, 1169, 1160, 1174, 1166, 1171, 1158, 1166, 1155, 1163, 1162, 1156, 1159, 1164, 1151, 1157, 1156, 1158, 1156, 1150, 1151, 1156, 1150, 1156, 1153, 1152, 1165, 1159, 1158, 1162, 1164, 1162, 1162, 1162, 1164, 1167, 1162]}, {'boa.File.eval': True, 'boa.TopLevelCmd.nextLine': True, 'boa.Expr.eval': True, 'boa.Var.eval': True, 'boa.ArithOpDivide.eval': True, 'boa.ArithOpPlus.eval': True, 'boa.ArithOpRemainder.eval': True, 'boa.Assign.eval': True, 'boa.Bool.eval': True, 'boa.BoolOpAnd.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpUnequal.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.If.eval': True, 'boa.Int.eval': True, 'boa.Project.eval': True, 'boa.Project.project': True, 'boa.Skip.eval': True, 'boa.With.eval': True, 'times': []}, {'boa.File.eval': True, 'boa.App.eval': True, 'boa.App.callFunc': True, 'boa.ArithOpDivide.eval': True, 'boa.ArithOpMinus.eval': True, 'boa.ArithOpPlus.eval': True, 'boa.ArithOpTimes.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpEqual.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.Fun.eval': True, 'boa.Int.eval': True, 'boa.Not.eval': True, 'boa.Project.eval': True, 'boa.Skip.eval': True, 'times': [3366, 1371, 1132, 1060, 1065, 1042, 1046, 1038, 1029, 1022, 1041, 1033, 1024, 1024, 1025, 1035, 1031, 1028, 1027, 1030, 1026, 1033, 1028, 1018, 1027, 1038, 1031, 1024, 1029, 1027, 1023, 1023, 1024, 1017, 1022, 1024, 1026, 1022, 1022, 1026, 1026, 1026, 1024, 1025, 1023, 1024, 1026, 1021, 1028, 1026]}, {'boa.File.eval': True, 'boa.Def.nextLine': True, 'boa.BObject.eval': True, 'boa.App.callFunc': True, 'boa.ArithOpDivide.eval': True, 'boa.ArithOpTimes.eval': True, 'boa.Assign.eval': True, 'boa.Bool.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpUnequal.eval': True, 'boa.CmpOpLess.eval': True, 'boa.If.eval': True, 'boa.Let.eval': True, 'boa.Not.eval': True, 'boa.With.eval': True, 'times': [3402, 1339, 1189, 1070, 1040, 1043, 1038, 1055, 1035, 1045, 1037, 1038, 1035, 1031, 1035, 1030, 1039, 1032, 1041, 1027, 1040, 1033, 1036, 1032, 1044, 1037, 1026, 1029, 1032, 1049, 1031, 1026, 1038, 1028, 1039, 1029, 1025, 1022, 1032, 1029, 1025, 1026, 1027, 1031, 1028, 1028, 1025, 1027, 1022, 1023]}, {'boa.File.eval': True, 'boa.TopLevelCmd.nextLine': True, 'boa.Def.nextLine': True, 'boa.Expr.eval': True, 'boa.Var.eval': True, 'boa.ArithOpDivide.eval': True, 'boa.ArithOpMinus.eval': True, 'boa.ArithOpRemainder.eval': True, 'boa.ArithOpTimes.eval': True, 'boa.Bool.eval': True, 'boa.BoolOpAnd.eval': True, 'boa.BoolOpOr.eval': True, 'boa.CmpOpUnequal.eval': True, 'boa.CmpOpLess.eval': True, 'boa.Copy.eval': True, 'boa.Fun.eval': True, 'boa.If.eval': True, 'boa.Let.eval': True, 'boa.Not.eval': True, 'boa.Project.eval': True, 'boa.Project.project': True, 'boa.Seq.eval': True, 'boa.With.eval': True, 'times': []}]
results_clean=[x for x in results if len(x['times'])>0]
df_results=pd.DataFrame.from_dict(results).fillna(False)
df_results_clean=df_results[df_results['times'].apply(lambda x: len(x) > 0)]
df_results_clean['avg']=df_results_clean['times'].apply(lambda x: average(x[10:]))
md=df_results_clean.sort_values(by=['avg'])
md = md.drop('times', axis=1)
print(md.describe(include='all'))
print(tabulate(md, tablefmt="pipe", headers="keys"))
# Out:
#        boa.App.callFunc boa.App.eval boa.ArithOpDivide.eval  \
# count                24           24                     24
# unique                2            2                      2
# top                True        False                   True
# freq                 14           14                     14
# mean                NaN          NaN                    NaN
# std                 NaN          NaN                    NaN
# min                 NaN          NaN                    NaN
# 25%                 NaN          NaN                    NaN
# 50%                 NaN          NaN                    NaN
# 75%                 NaN          NaN                    NaN
# max                 NaN          NaN                    NaN
#
#        boa.ArithOpMinus.eval boa.ArithOpPlus.eval boa.ArithOpRemainder.eval  \
# count                     24                   24                        24
# unique                     2                    2                         2
# ...

# %%
nums = list(range(0, len(results_clean)))

avgs=[average(x['times'][10:]) for x in results_clean]

fig, ax = plt.subplots()
plt.xticks(rotation=90)
plt.bar(nums, tuple(avgs))

plt.figure(figsize=(10,10))
handles=[]
i=0
for x in results_clean:
    # plt.axhline(y=median(v))
    h, = plt.plot(x['times'], label=i)
    handles.append(h)
    i = i + 1
plt.legend(handles=handles)
plt.show()

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor


regressor = DecisionTreeRegressor()
cvf = regressor.fit(df_results_clean.filter(regex='^boa.*', axis=1), df_results_clean.filter(regex='avg', axis=1))
reg_tree=cross_val_score(regressor, df_results_clean.filter(regex='^boa.*', axis=1), df_results_clean.filter(regex='avg', axis=1), cv=10)

# %%
dot_data = tree.export_graphviz(cvf, out_file=None, 
                     feature_names=list(df_results_clean.filter(regex='^boa.*', axis=1)),  
                     #class_names=iris.target_names,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
import graphviz
from sklearn import tree
dot_data = tree.export_graphviz(cvf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph
